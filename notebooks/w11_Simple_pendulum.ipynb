# %% [markdown]
# The code in this notebook has been adapted from the work of Zhongy et al. and Greydanus et al.
#
# Their code is available in the following repositories :[
# Symplectic-ODENet](https://github.com/Physics-aware-AI/Symplectic-ODENet) and [hamiltonian-nn](https://github.com/greydanus/hamiltonian-nn)

# %% [markdown]
# ## Colab

# %%
# Mount your google drive (currently not required)
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Imports

# %%
# !pip install torchdiffeq
# Out:
# Requirement already satisfied: torchdiffeq in c:\programdata\anaconda3\envs\pds\lib\site-packages (0.2.2)
# Requirement already satisfied: scipy>=1.4.0 in c:\programdata\anaconda3\envs\pds\lib\site-packages (from torchdiffeq) (1.8.0)
# Requirement already satisfied: torch>=1.3.0 in c:\programdata\anaconda3\envs\pds\lib\site-packages (from torchdiffeq) (1.10.2)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\programdata\anaconda3\envs\pds\lib\site-packages (from scipy>=1.4.0->torchdiffeq) (1.21.5)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\envs\pds\lib\site-packages (from torch>=1.3.0->torchdiffeq) (3.10.0.2)

# %%
# import autograd
# import autograd.numpy as np

import scipy.integrate
solve_ivp = scipy.integrate.solve_ivp

import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset, DataLoader,random_split
import torch

from torchdiffeq import odeint_adjoint as odeint_adjoint # func needs to be nn.Module for odeint_adjoint to work
from torchdiffeq import odeint as odeint

import time as time

# %%
# set device to GPU if available otherwise use CPU
def set_device():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    if device.type == 'cuda':
        # if there is a GPU
        print (f'Device Availble: {torch.cuda.get_device_name(0)}') 
    else :
        print(device)
    return device
    
device = set_device()
# Out:
# cpu

# %% [markdown]
# ## Data Generation
#
# Similar to https://github.com/Physics-aware-AI/Symplectic-ODENet/blob/master/experiment-single-force/data.py

# %% [markdown]
# ### Dynamics

# %%
def pendulum_H(q, p, m, g, l):
    H = (1/(2*m*(l**2)))*p**2 + m*g*l*(1-torch.cos(q))  
    return H

def hamiltonian_fn_pend(coords, m, g, l):
    q, p = torch.split(coords,1)
    H = pendulum_H(q,p, m, g, l)
    return H

def coord_derivative_pend(t, coords, C, m, g, l, u_func, g_func):

    if coords.requires_grad is not True:
      coords.requires_grad=True
    H = hamiltonian_fn_pend(coords, m, g, l)

    # derivaties of the hamiltornian function wrt the generalized coordinates
    dcoords = torch.autograd.grad(H, coords, create_graph=True)
    
    dHdq, dHdp = torch.split(dcoords[0],1)

    device = dHdq.device

    u = u_func.forward(t)
    G = g_func.forward(coords)

    dqdt = dHdp + G[0]*u
    dpdt = -dHdq - C*dHdp + G[1]*u

    return dqdt, dpdt

def dynamics_fn_pend(t, coords, C, m, g, l, u_func, g_func):

    dqdt, dpdt = coord_derivative_pend(t, coords, C, m, g, l, u_func, g_func)
    # symplectic gradient
    S = torch.hstack((dqdt, dpdt)) 
    return S

# %% [markdown]
# ### Trajectory and energy

# %%
def chirp_fun(t,T=1.5,f0=1,f1=50, scale =1):
    # https://en.wikipedia.org/wiki/Chirp
    c = (f1-f0)/T
    return torch.sin(2*torch.pi*(c*t**2/2 + f0*t))*scale

def multi_sine(t, scale = 0.5):
    f = torch.tensor([2,10,3,4], device = t.device).unsqueeze(dim=1)
    A = torch.tensor([2,0.5,0.3,0.8], device = t.device).unsqueeze(dim=1)
    return (A*torch.sin(2*torch.pi*t*f)).sum(dim=0)*scale

def step_fun(t, t1=0.05, scale=0.1):
    f = torch.zeros_like(t)
    f[t < t1] = 0
    f[~(t < t1)] = scale
    return f

class U_FUNC():
    def __init__(self, utype=None, params={}):
        super(U_FUNC).__init__()
        self.utype = utype
        self.params = params # dict containing params for the input function
        self.params['T'] = 1.5
        self.params['f0'] = 1
        self.params['f1'] = 10
        self.params['scale'] = 1

    def forward(self, t):  
        ''' time dependent input '''
        if self.utype == 'tanh':
            u = (-torch.tanh((t-0.75)*4)+1)/100
        elif self.utype == 'chirp':
            u = chirp_fun(t,
                            T=self.params['T'],
                            f0=self.params['f0'],
                            f1=self.params['f1'],
                            scale = self.params['scale'])
        elif self.utype == 'multisine':
            u = multi_sine(t, scale = self.params['scale'])
        elif self.utype == 'step':
            u = step_fun(t, t1=0.5)
        elif self.utype is None:
            u = torch.zeros(t.shape, device=t.device)
        u.requires_grad=False
        return u

class G_FUNC():
    def __init__(self, gtype=None, params={}):
        super(G_FUNC).__init__()
        self.gtype = gtype
        self.params = params # dict containing params on
    
    def forward(self, coords): 
        ''' state dependent input '''
        q,p = torch.split(coords,1,dim=-1)
        if self.gtype=='simple':
            if len(q.shape)==1:
                dimension = 0
            else:
                dimension = 1
            g = torch.stack((torch.zeros(q.shape[0]),torch.ones(q.shape[0])), dim=dimension)
        if self.gtype is None:
            g = torch.zeros(q.shape[0], 2, device = q.device)
        g.requires_grad = False
        return g

def get_trajectory_pend(device, time_steps, Ts, y0, noise_std, C, m, g, l, u_func, g_func):
    '''
    Similar to SymODEN repository
    '''

    t_eval = torch.linspace(1, time_steps, time_steps, device=device) * Ts # evaluated times vector
    
    # get initial state
    if y0 is None:
        y0 = torch.rand(2)*4.-2 # uniform law [-2,2]
        y0[1]=0

    q_p = odeint(func = lambda t, coords : dynamics_fn_pend(t, coords, C, m, g, l, u_func, g_func) , y0 = y0, t = t_eval, method = 'rk4', options=dict(step_size=Ts)) 

    q, p = torch.chunk(q_p,2,1)

    # add noise 
    q = q+torch.randn(q.shape, device=device)*noise_std 
    p = p+torch.randn(p.shape, device=device)*noise_std 

    return q.detach().squeeze(), p.detach().squeeze(), t_eval.detach()

# %%
def energy_pendulum(theta_dot, theta, m, g, l):
    '''
    This function calculates the energy of the simple pendulum in function of 
    the angle theta and it's derivative
    Inputs :
        - theta_dot : 
        - theta : 
        - m : pendulum mass 
        - g : 
        - l : length of arm
    Outputs:
        - E () : Energy of the system
    '''
    E = (1/2)*m*(l**2)*theta_dot**2 + m*g*l*(1-torch.cos(theta))
    return E
    
def get_energy_pendulum(t_eval, u_func, g_func,  q,p, C, m, g, l):

    energy = []
    derivatives = []

    coords = torch.stack((q, p),dim=1)
    for i in range(len(t_eval)):

      dqdt, dpdt = coord_derivative_pend(t_eval[i], coords[i,:], C, m, g, l, u_func, g_func)

      theta_dot = dqdt
      theta = coords[i,0]

      energy.append(energy_pendulum(theta_dot, theta, m, g, l))
      derivatives.append(torch.hstack((dqdt, dpdt)))

    energy = torch.hstack(energy).detach() # torch.cat(energy, axis=0 ).detach()
    derivatives = torch.vstack(derivatives).detach()
    return energy.squeeze(), derivatives.squeeze()

# %%
device = set_device()
time_steps = 40
y0 = None
noise_std = 0.0
Ts = 0.05
C = 0.0
m = 1
g = 9.81
l = 1
utype = 'chirp'
u_func = U_FUNC(utype=utype)
u_func.params['T'] = 2.0
u_func.params['f0'] = 0
u_func.params['f1'] = 1
u_func.params['scale'] = 1
gtype='simple'
g_func = G_FUNC(gtype=gtype)
# Out:
# cpu

# %%
q, p, t_eval = get_trajectory_pend(device, time_steps, Ts, y0, 
noise_std, C, m, g, l, u_func, g_func)

energy, derivatives = get_energy_pendulum(t_eval, u_func, g_func, q,p, C, m, g, l)

# %%
input = u_func.forward(t=t_eval)
plot_traj_pend(t_eval, q, p, energy, input) # sanity check

# %% [markdown]
# #### Multiple trajectories

# %%
def multiple_trajectories(time_steps, num_trajectories, device, Ts, y0, 
                                noise_std, C, m, g, l, u_func, g_func, coord_type = 'hamiltonian'):
    '''
    
    '''
    # the first trajectory
    q, p, t_eval = get_trajectory_pend(device, time_steps, Ts, y0, 
                                noise_std, C, m, g, l, u_func, g_func)
    energy, derivatives = get_energy_pendulum(t_eval, u_func, g_func, q, p, C, m, g, l)
    energy = energy.squeeze()
    q = q.squeeze()
    if coord_type == 'hamiltonian':
        p = p.squeeze()
    if coord_type == 'newtonian':
        p = derivatives[:,0].squeeze()
        
    derivatives = derivatives.unsqueeze(dim=0)

    for _ in range(num_trajectories-1):
        # the trajectories 2 to num_trajectories
        q_n, p_n, _ = get_trajectory_pend(device, time_steps, Ts, y0, 
                                noise_std, C, m, g, l, u_func, g_func)
        energy_n, derivatives_n = get_energy_pendulum(t_eval, u_func, g_func, q_n, p_n, C, m, g, l)

        energy = torch.vstack((energy, energy_n.squeeze()))
        q = torch.vstack((q, q_n.squeeze()))

        if coord_type == 'hamiltonian':
            p = torch.vstack((p, p_n.squeeze()))
            p = p.squeeze()
        if coord_type == 'newtonian':
            p = torch.vstack((p, derivatives_n[:,0].squeeze()))
        
        derivatives  = torch.vstack((derivatives, derivatives_n.unsqueeze(dim=0)))

    if num_trajectories == 1 :
        # so that the vectors will have the correct dimensions if only 1
        # trajectory is requested
        q = q.unsqueeze(dim=0) 
        p = p.unsqueeze(dim=0) 
        energy = energy.unsqueeze(dim=0) 
    return q.t(), p.t(), t_eval, energy.t(), torch.permute(derivatives, (1,0,2)) #

# %%
q, p, t_eval, energy, derivatives = multiple_trajectories(time_steps=time_steps, num_trajectories=2, device=device, Ts=Ts, y0=y0, 
                                noise_std=noise_std, C=C, m=m, g=g, l=l, u_func=u_func, g_func=g_func, coord_type = 'hamiltonian')

# %%
shapes = [print(i.shape) for i in [q, p, t_eval, energy, derivatives]]
# Out:
# torch.Size([200, 2])
# torch.Size([200, 2])
# torch.Size([200])
# torch.Size([200, 2])
# torch.Size([200, 2, 2])

# %%
plot_traj_pend(t_eval, q[:,0], p[:,0], energy[:,0], coord_type = 'hamiltonian') # sanity check

# %% [markdown]
# ### Dataset & Dataloader

# %%
class TrajectoryDataset(Dataset):
    '''
    
    '''
    def __init__(self, q, p, t_eval):
        self.q = q
        self.p = p
        self.t_eval = t_eval

    def __len__(self):
        return self.q.shape[1]

    def __getitem__(self, idx):
        q = self.q[:,idx]
        p = self.p[:,idx]
        t_eval = self.t_eval#[idx].squeeze()
        x = torch.stack((q,p),dim=1)#.t().float()
        return x, t_eval

# %%
def data_loader(q, p, t_eval, batch_size, shuffle = True, proportion = 0.5):
    '''
    '''
    # split  into train and test 
    if proportion:

        full_dataset = TrajectoryDataset(q, p, t_eval)

        train_size = int(proportion * len(full_dataset))
        test_size = len(full_dataset) - train_size

        train, test = random_split(full_dataset, [train_size, test_size])

        # q_train, q_test = train_test_split_torch(q, test_size=proportion, random_state=0)
        # p_train, p_test = train_test_split_torch(p, test_size=proportion, random_state=0)

        # test = TrajectoryDataset(q_test, p_test, t_eval)

        test_loader = DataLoader(
            test,
            batch_size,
            shuffle
            )    
    else:
      train = TrajectoryDataset(q, p, t_eval)
      # if proportion is set to None don't split the dataset
      q_train = q
      p_train = p
      t_eval_train = t_eval
      test_loader = None

    # load the training data into a custom pyotorch dataset
    # train = TrajectoryDataset(q_train, p_train, t_eval)

    # create the dataloader object from the custom dataset
    train_loader = DataLoader(
        train,
        batch_size,
        shuffle
        )
       
    return train_loader, test_loader

# %%
q, p, t_eval,_,_=q, p, t_eval, energy, derivatives = multiple_trajectories(time_steps=time_steps, num_trajectories=10, device=device, Ts=Ts, y0=y0, noise_std=noise_std, C=C, m=m, g=g, l=l, u_func=u_func, g_func=g_func, coord_type = 'hamiltonian')

# %%
train_loader, test_loader = data_loader(q, p, t_eval, batch_size=3, shuffle = True, proportion = 0.5)

# %%
# sanity checks
x_tt, t_eval_tt = next(iter(test_loader))
print(x_tt.shape)
# Out:
# torch.Size([3, 200, 2])

# %%
# sanity checks
x_tt, t_eval_tt = next(iter(train_loader))
print(x_tt.shape)
# Out:
# torch.Size([3, 200, 2])

# %%
t_eval_tt.shape
# Out:
# torch.Size([3, 200])

# %%
plot_traj_pend(t_eval_tt[0], x_tt[0,:,0], x_tt[0,:,1], coord_type = 'hamiltonian')

# %% [markdown]
# ## Utils

# %%
def count_parameters(model):
    '''
    from https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/9
    '''
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ## Plots

# %%
def plot_traj_pend(t_eval, q, p, energy=torch.tensor(False), input=torch.tensor(False), coord_type = 'hamiltonian'):
    '''
    This function plots the generalised variable q p in function of the evaluation 
    time
    Inputs:
      t_eval ()
      q ()
      p ()
    Outputs:
      None
    '''
    if torch.any(energy):
      if torch.any(input):
        fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(12, 4),constrained_layout=True)#, sharex=True)# , sharey=True)
        ax3.plot(t_eval, energy, label='energy')
        
        #ax1.legend()
        ax3.set_title('Energy', fontsize=10)
        ax3.set_xlabel('time (s)')
        ax3.set_ylabel('E')
        ax3.set_ylim((0,torch.max(energy)*1.1))

        ax4.plot(t_eval, input, label='energy')
        ax4.set_title('Input', fontsize=10)
        ax4.set_xlabel('time (s)')
        ax4.set_ylabel('U')
        # ax4.set_ylim((0,torch.max(input)*1.1))
      else :
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(12, 4),constrained_layout=True)#, sharex=True)# , sharey=True)
        ax3.plot(t_eval, energy, label='energy')

        #ax1.legend()
        ax3.set_title('Energy', fontsize=10)
        ax3.set_xlabel('time (s)')
        ax3.set_ylabel('E')
        ax3.set_ylim((0,torch.max(energy)*1.1))
    else:
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4),constrained_layout=True, sharex=True)# , sharey=True)


    ax1.plot(t_eval, q, label='q')
    ax2.plot(t_eval, p, label='p')

    #ax1.legend()
    ax1.set_title('generalized position (q)', fontsize=10)
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel('q')

    #ax2.legend()
    ax2.set_title('generalized momentum (p)', fontsize=10)
    ax2.set_xlabel('time (s)')
    ax2.set_ylabel('p')

    fig.suptitle('Trajectory of the generalized coordinates', fontsize=12)
    

    if coord_type == 'newtonian':
        ax2.set_title(r'$\dot{q}[rad/s]$', fontsize=10)
        ax2.set_ylabel(r'$\dot{q}[rad/s]$')

    plt.show()
    return

# %% [markdown]
# ## Models

# %% [markdown]
# #### Base models

# %%
def choose_nonlinearity(name):
    '''
    From the SymODEN repository

    Description:

    Inputs:

    Outpus:
      
    '''
    nl = None
    if name == 'tanh':
        nl = torch.tanh
    elif name == 'x+sin(x)^2':
        nl = lambda x: x + torch.sin(x).pow(2)
    else:
        raise ValueError("nonlinearity not recognized")
    return nl

class hidden_Layer(torch.nn.Module):
    '''
    Fully connected layer with activation function
    '''
    def __init__(self,hidden_dim, activation='tanh'):
        super().__init__()
        self.fc = torch.nn.Linear(hidden_dim,hidden_dim)
        self.activation = choose_nonlinearity(activation)# activation function

    def forward(self, x):
        x=self.activation(self.fc(x))
        return x


class MLP(torch.nn.Module):
    '''
    MLP with number of hidden layers as a parameter
    '''
    def __init__(self, input_dim=2, hidden_dim=90, nb_hidden_layers=4, output_dim=1, activation='x+sin(x)^2'):
        super(MLP, self).__init__()
        self.fc1 = torch.nn.Linear(input_dim, hidden_dim)
        self.hidden_layers = torch.nn.Sequential(
            *(hidden_Layer(hidden_dim, activation)
              for _ in range(nb_hidden_layers))
        ) # trick from EE-559 to define hidden layers
        self.fc2 = torch.nn.Linear(hidden_dim, output_dim)
        self.activation = choose_nonlinearity(activation) # activation function

    def forward(self, x):
        h = self.activation( self.fc1(x) )
        h = self.hidden_layers(h) 
        return self.fc2(h)

# %%
model = MLP(input_dim=2, hidden_dim=90, nb_hidden_layers=1, output_dim=1, activation='tanh')

# %%
count_parameters(model)
# Out:
# 8551

# %% [markdown]
# ### U-ODE-HNN

# %%
class U_ODE_HNN(torch.nn.Module):
    '''
    Modified version of the original SymODEN_R module
    Equivalent of unconstrained ODE HNN from the report
    Architecture for input (q, p, u), 
    where q and p are tensors of size (bs, n) and u is a tensor of size (bs, 1)
    '''
    def __init__(self, input_dim, H_net=None, M_net=None, V_net=None, g_net=None, device=None,
                    assume_canonical_coords=True, baseline=True, structure=False):
        super(U_ODE_HNN, self).__init__()
        self.baseline = baseline
        self.structure = structure

        self.H_net = H_net
        self.g_net = g_net

        self.device = device
        self.assume_canonical_coords = assume_canonical_coords

        self.input_dim = input_dim
        
        # add a learnable dissipation coefficient
        self.C_dissip = torch.nn.Parameter(torch.tensor([0.5]))  # torch.nn.Parameter(torch.rand(1))
        self.C_dissip.requires_grad = True

    def forward(self, t, x):
        with torch.enable_grad():
            q_p = x

            q, p = torch.chunk(x,2,dim=-1)

            q_p.requires_grad_(True)

            H = self.H_net(q_p)

            dH = torch.autograd.grad(H.sum(), q_p, create_graph=True)

            dH = dH[0]

            dHdq , dHdp = torch.chunk(dH,2,dim=-1)

            dqdt = dHdp 

            dpdt = -dHdq - self.C_dissip*dHdp

            # symplectic gradient 
            S_h = torch.cat((dqdt, dpdt), 
                            dim=-1) 
            return S_h

# %%
H_net = MLP(input_dim=2, hidden_dim=90, nb_hidden_layers=4, output_dim=1, activation='tanh')

# %%
model = U_ODE_HNN(input_dim=2, H_net=H_net, M_net=None, V_net=None, g_net=None, device=None,
                    assume_canonical_coords=True, baseline=True, structure=False)

# %%
s_h = model(t_eval_tt, x_tt) # sanity check
print(s_h.shape)
# Out:
# torch.Size([3, 200, 2])

# %% [markdown]
# ### Nes_HDNN

# %%
class Nes_HDNN(torch.nn.Module):
    '''
    Modified version of the original SymODEN_R module from symoden repository
    Similar to unconstrained ODE HNN from the report

    '''
    def __init__(self, u_func = None, G_net=None, H_net=None, device=None):
        super(Nes_HDNN, self).__init__()
        self.H_net = H_net
        self.G_net = G_net
        self.u_func = u_func

        self.device = device
        
        # add learnable dissipation coefficients
        self.C = torch.nn.Parameter(torch.tensor([0.02]).sqrt()) # torch.nn.Parameter(torch.randn(1)+1) # torch.nn.Parameter(torch.tensor([0.5])) 
        self.C.requires_grad = True


    def forward(self, t, x):
        with torch.enable_grad():
            q_p = x

            # q1,p1,q2,p2 = torch.chunk(x,4,dim=-1)

            q_p.requires_grad_(True)

            H = self.H_net(q_p)

            # .sum() to sum up the hamiltonian funcs of a batch
            dH = torch.autograd.grad(H.sum(), q_p, create_graph=True)

            dH = dH[0]

            dHdq, dHdp= torch.chunk(dH,2,dim=-1)
            

            G = self.G_net.forward(q_p)

            if self.u_func:
                u = self.u_func.forward(t)
            else:
                u = torch.tensor([0.0])
            dqdt = dHdp 
            dpdt = -dHdq + (G[:,1].T*u).unsqueeze(dim=1) # - self.C.pow(2)*dHdp1 

            # symplectic gradient 
            S_h = torch.cat((dqdt, dpdt), 
                            dim=-1) 
            
            return S_h

    def freeze_G_net(self, freeze=True): 
        """
        Only freez the G_net parameters
        Inputs
            freeze(bool) : True = freeze the parameters; False = don't
        
        outputs:
            None

        """
        for param in self.G_net.parameters(): 
            param.requires_grad = (not freeze)

    def freeze_H_net(self, freeze=True): 
        """
        Only freez the H_net parameters
        Inputs
            freeze(bool) : True = freeze the parameters; False = don't
      
        outputs:
            None
        """
        for param in self.H_net.parameters(): 
            param.requires_grad = (not freeze)

# %%
G_net = MLP(input_dim=2, hidden_dim=90, nb_hidden_layers=2, output_dim=2, activation='tanh')
H_net = MLP(input_dim=2, hidden_dim=90, nb_hidden_layers=1, output_dim=1, activation='tanh')

# %%
G_net = g_func

# %%
model = Nes_HDNN(u_func = u_func, G_net=G_net, H_net=H_net, device=device)

# %%
model(t_eval_tt[:,1],x_tt[:,1,:])
# Out:
# tensor([[-0.0239,  0.0052],
#         [-0.0509,  0.0324],
#         [-0.0168,  0.0027]], grad_fn=<CatBackward0>)

# %% [markdown]
# ### Autoencoder

# %%
class Autoencoder(torch.nn.Module):
    '''Just a MLP
    From the SymODEN repository
    '''
    def __init__(self, nb_hidden_layers=1,  hidden_dim=64, enc_in_dim=2, 
                 enc_out_dim=2, dec_in_dim = 2, dec_out_dim = 2, activation='tanh'):
        super(Autoencoder, self).__init__()

        self.encoder = MLP(input_dim=enc_in_dim, hidden_dim=hidden_dim, 
                           nb_hidden_layers=nb_hidden_layers, output_dim=enc_out_dim, activation=activation)
        self.decoder = MLP(input_dim=dec_in_dim, hidden_dim=hidden_dim, 
                           nb_hidden_layers=nb_hidden_layers, output_dim=dec_out_dim, activation=activation)

    def forward(self, x): # x is (q, q_dot)
        # q,p=torch.split(x,1,dim=2)
        p_hat = self.encoder(x) # coordinates in the latent space

        # z_h = torch.cat((q,z),dim=2) # input known q and encoded z into decoder
        q_dot_hat = self.decoder(p_hat) # coordinates back in the original space but using the decoder

        return p_hat, q_dot_hat

# %%
autoencoder = Autoencoder(nb_hidden_layers=1,  hidden_dim=64, enc_in_dim=2, 
                 enc_out_dim=1, dec_in_dim = 1, dec_out_dim = 2, activation='tanh')

# %%
count_parameters(autoencoder)
# Out:
# 8835

# %%
x_tt.shape
# Out:
# torch.Size([3, 40, 2])

# %%
test = x_tt[:,:5,:]

# %%
test.shape
# Out:
# torch.Size([3, 5, 2])

# %%
test[:,0,:].shape
# Out:
# torch.Size([3, 2])

# %%
z,x = autoencoder(test[:,0,:])

# %%
z
# Out:
# tensor([[-0.0269],
#         [-0.0547],
#         [-0.0416]], grad_fn=<AddmmBackward0>)

# %%
x
# Out:
# tensor([[0.0984, 0.0463],
#         [0.1011, 0.0512],
#         [0.0999, 0.0489]], grad_fn=<AddmmBackward0>)

# %%
def train_autoencoder():

    lr = 1e-3
    Ts = 0.05

    optim = torch.optim.Adam(model.parameters(), lr, weight_decay=1e-4)

    stats = {'train_loss': [], 'test_loss': []}
    w=torch.tensor([0.1,1.0], device=device)

    for step in range(epochs):
        
        train_loss = 0
        test_loss = 0

        t1 = time.time()

        #horizon = select_horizon(step)

        # Training
        for x, t_eval in iter(train_loader):
            x = torch.permute(x, (1,0,2)) # to have the same dimensions as odeint
            t_eval = t_eval[0,:horizon] #t_eval.squeeze()
           
            train_z, train_x_hat = autoencoder(x)
            train_loss_mini = L2_loss(x[:, :, :], train_x_hat[:],w) # batch loss
            
            train_loss = train_loss + train_loss_mini # epoch loss

            train_loss_mini.backward() 
            optim.step() 
            optim.zero_grad() 

        t2 = time.time()
        train_time = t2-t1

        # Testing
        if test_loader:
            if not (step%10):
                for x, t_eval in iter(test_loader):
                    x = torch.permute(x, (1,0,2)) 

                    t_eval = t_eval[0,:horizon] # t_eval.squeeze()

                    
                    test_x_hat = odeint(model, x[0, :, :], t_eval, method='rk4', options=dict(step_size=Ts))
                    
                    test_loss_mini = L2_loss(x[:horizon, :, :], test_x_hat[:horizon],w) 
                    test_loss = test_loss + test_loss_mini
                
                print('epoch', step, '| train loss ', train_loss.item(), '| test loss', test_loss.item(), '| train time:',train_time)
                stats['test_loss'].append(test_loss.item())
        else:
            if not (step%10):
                print('epoch', step, '| train loss ', train_loss.item(),'| train time:',train_time)

        # logging
        stats['train_loss'].append(train_loss.item())
        
    return stats

# %% [markdown]
# # Training

# %% [markdown]
# ## Train functions

# %%
def L2_loss(u, v, w = False, dim = (0,1), param = 'L2'):
    # u nominal
    # v approximate
    # u and v expected with shape : [time_steps, batch_size , (q1,p1,q2,p1)] 
    if param == 'L2':
        # mean only over time steps and batch_size 
        loss = (((u-v)).pow(2)).mean(dim = dim ).sum()
    elif param == 'L2weighted2':
        loss = (((u-v).mul(w)).pow(2)).mean(dim = dim ).sum()
    return ((u-v)*w).pow(2).mean()

# %%
def load_model(model_name='U_ODE_HNN'):
    H_net = MLP(input_dim=2, hidden_dim=130, output_dim=1, nonlinearity='tanh', bias_bool=True)

    if model_name == 'U_ODE_HNN':
        model = U_ODE_HNN(input_dim=2, H_net=H_net, M_net=None, V_net=None, g_net=None, device=device,
                            assume_canonical_coords=True, baseline=True, structure=False)
    if model_name == 'Newtonian_U_ODE_HNN':
        model = Newtonian_U_ODE_HNN(input_dim=2, H_net=H_net, M_net=None, V_net=None, g_net=None, device=device,
                            assume_canonical_coords=True, baseline=True, structure=False)

    model.to(device)
    return model

# %%
def load_model_nes_hdnn(device, g_func=None, u_func=None, hidden_dim=90, nb_hidden_layers=4):
    H_net = MLP(input_dim=2, hidden_dim=60, nb_hidden_layers=2, output_dim=1, activation='x+sin(x)^2')
    if g_func is None :
        G_net = MLP(input_dim=2, hidden_dim=40, nb_hidden_layers=1, output_dim=2, activation='tanh')
        model = Nes_HDNN(u_func=u_func, G_net=G_net, H_net=H_net, device=device)
    else :      
        model = Nes_HDNN(u_func=u_func, G_net=g_func, H_net=H_net, device=device)
    model.to(device) 

    return model

# %%
def select_horizon_list(step, horizon_list = [50,100,150,200,250,300], switch_steps = [200,200,200,150,150,150]):
    '''
    Description:

    Inputs:

    Outpus:
      
    '''
    # throw error if 
    assert len(horizon_list)==len(switch_steps), ' horizon_list and switch_steps must have same length'

    if step <=switch_steps[0]:
        horizon = horizon_list[0]
        if step==0:
            print('horizon length :', horizon)

    for i in range(len(switch_steps)):
      if (step > sum(switch_steps[0:i]))&(step <= sum(switch_steps[0:i+1])):
          horizon = horizon_list[i]
          if step==sum(switch_steps[0:i])+1:
              print('horizon length :', horizon)

    if step > sum(switch_steps):
        horizon = horizon_list[-1]
        if step== sum(switch_steps)+1:
            print('horizon length :', horizon)
    return horizon

# %%
def train(model, Ts, train_loader, test_loader, w, horizon=False, horizon_type=False,
          horizon_list = [50,100,150,200,250,300], 
          switch_steps = [200,200,200,150,150,150],
          epochs = 20, 
          loss_type = 'L2'):
    '''
    Description:

    Inputs:

    Outpus:  
    '''
    ## TODO : make a function for one epoch
    ## first training steps on smaller amount of time_steps

    
    lr = 1e-3

    optim = torch.optim.AdamW(model.parameters(), lr, weight_decay=1e-4) # Adam

    logs = {'train_loss': [], 'test_loss': []}
    # weight for loss function

    for step in range(epochs):
        
        train_loss = 0
        test_loss = 0
        t1 = time.time()

        if horizon_type == 'schedule':
            pass
        #     horizon, num_steps= select_horizon_wschedule(step,optim,
        #                                                   epoch_number,
        #                                                   switch_steps)
        #     if num_steps :
        #         scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optim, num_steps)
        elif horizon_type == 'auto': 
            horizon = select_horizon_list(step, horizon_list, switch_steps)

        model.train()
        for x, t_eval in iter(train_loader): # we don't really need u since the model knows u_func
            # x is [batch_size,(q1,p1,q2,p1),time_steps]

            t_eval = t_eval[0,:horizon]
            
            train_x_hat = odeint(model, x[:, 0, :], t_eval, method='rk4', options=dict(step_size=Ts))            
            # train_x_hat is [time_steps, batch_size, (q1,p1,q2,p1)] 
            #train_loss_mini = L2_loss(torch.permute(x[:, :, :horizon], (2,0,1)) , train_x_hat[:horizon,:,:],w)#[:,:horizon])

            train_loss_mini = L2_loss(torch.permute(x[:, :horizon, :], (1,0,2)) , train_x_hat[:horizon,:,:], w, param = loss_type)
            # after permute x is [time_steps, batch_size, (q1,p1,q2,p1),]

            # loss(u, v, w = False, dim = (0,1), param = loss_type)
            # if not step%10:
            #     t_plot = time.time()
            #     training_plot(t_eval, train_x_hat[:horizon,:,:], x[:, :, :horizon])
            #     print('plot time :' , time.time()-t_plot)

            train_loss = train_loss + train_loss_mini.item()

            train_loss_mini.backward() 
            optim.step() 
            optim.zero_grad()
            # if (horizon == 'schedule') and do_step:
            #   scheduler.step()


        t2 = time.time()
        train_time = t2-t1

        model.eval()
        if test_loader: 
            with torch.no_grad(): # we won't need gradients for testing
                if not (step%10): # run validation every 10 steps
                    for x, t_eval in iter(test_loader):
                        # run test data
                        t_eval = t_eval[0,:horizon]
      
                        test_x_hat = odeint(model, x[:, 0, :], t_eval, method='rk4', options=dict(step_size=Ts))      
                        #test_loss_mini = L2_loss(torch.permute(x[:, :, :horizon], (2,0,1)) , test_x_hat[:horizon,:,:],w)
                        test_loss_mini = L2_loss(torch.permute(x[:, :horizon, :], (1,0,2)) , test_x_hat[:horizon,:,:], w, param = loss_type)
              

                        test_loss = test_loss + test_loss_mini.item()
                    test_time = time.time()-t2
                    print('epoch {:4d} | train time {:.2f} | train loss {:8e} | test loss {:8e} | test time {:.2f}  '
                          .format(step, train_time, train_loss, test_loss,test_time))
                    logs['test_loss'].append(test_loss)
                    
                else:
                    print('epoch {:4d} | train time {:.2f} | train loss {:8e} '
                          .format(step, train_time, train_loss))
        else:
            print('epoch {:4d} | train time {:.2f} | train loss {:8e} '
                  .format(step, train_time, train_loss))
        
        # logging
        logs['train_loss'].append(train_loss)
    return logs

# %%
def load_data_device(time_steps, num_trajectories, device, batch_size, proportion, shuffle, Ts, y0, 
                                noise_std, C, m, g, l, u_func, g_func, coord_type = 'hamiltonian'):
    # create trajectories
    q, p, t_eval,_,_ = multiple_trajectories(time_steps=time_steps, num_trajectories=num_trajectories, device=device, Ts=Ts, y0=y0, 
                                noise_std=noise_std, C=C, m=m, g=g, l=l, u_func=u_func, g_func=g_func, coord_type = coord_type)

    q=q.to(device) 
    p=p.to(device) 
    t_eval=t_eval.to(device) 

    # dataloader to load data in batches
    train_loader, test_loader = data_loader(q, p, t_eval, batch_size, shuffle = shuffle, proportion = proportion)
    return train_loader, test_loader

# %% [markdown]
# ## training

# %%
device = 'cpu' # for some reason it is faster on CPU
# probably because the model doesn't have many parameters and the ode solver
# can't do many calculations in parallel ?

# %%
device = set_device()
time_steps = 40
y0 = None
noise_std = 0.0
Ts = 0.05
C = 0.0
m = 1
g = 9.81
l = 1
utype = 'chirp'
u_func = U_FUNC(utype=utype)
u_func.params['T'] = 2.0
u_func.params['f0'] = 0
u_func.params['f1'] = 1
u_func.params['scale'] = 1
gtype='simple'
g_func = G_FUNC(gtype=gtype)
# Out:
# cpu

# %%
train_loader, test_loader = load_data_device(time_steps=time_steps, num_trajectories=125, device=device, batch_size=100, proportion=0.8, shuffle=False, Ts=Ts, y0=y0, 
                                noise_std=noise_std, C=C, m=m, g=g, l=l, u_func=u_func, g_func=g_func, coord_type = 'hamiltonian')

# %%
model = load_model_nes_hdnn(device, g_func=None, u_func=u_func)
count_parameters(model)
# Out:
# 9404

# %%
w = torch.tensor([1.0,1.0], device = device)
horizon_list = [20,25,30,35,40]
switch_steps = [100,100,100,100,100]
epoch_num = sum(switch_steps)
print(epoch_num)
# Out:
# 500

# %%
stats = train(model, Ts, train_loader, test_loader, w, horizon=False, horizon_type='auto',
          horizon_list = horizon_list, 
          switch_steps = switch_steps,
          epochs = epoch_num, 
          loss_type = 'L2weighted2')
# Out:
# horizon length : 20
# epoch    0 | train time 0.30 | train loss 3.347057e+00 | test loss 4.267145e+00 | test time 0.11
# horizon length : 20
# epoch    1 | train time 0.33 | train loss 3.234042e+00
# epoch    2 | train time 0.30 | train loss 3.123638e+00
# epoch    3 | train time 0.29 | train loss 3.015505e+00
# epoch    4 | train time 0.28 | train loss 2.909337e+00
# epoch    5 | train time 0.28 | train loss 2.804860e+00
# epoch    6 | train time 0.29 | train loss 2.701853e+00
# epoch    7 | train time 0.36 | train loss 2.600261e+00
# epoch    8 | train time 0.29 | train loss 2.500166e+00
# epoch    9 | train time 0.32 | train loss 2.401639e+00
# epoch   10 | train time 0.30 | train loss 2.304636e+00 | test loss 3.025785e+00 | test time 0.10
# epoch   11 | train time 0.28 | train loss 2.208981e+00
# epoch   12 | train time 0.29 | train loss 2.114410e+00
# epoch   13 | train time 0.28 | train loss 2.020684e+00
# epoch   14 | train time 0.31 | train loss 1.927675e+00
# epoch   15 | train time 0.35 | train loss 1.835399e+00
# epoch   16 | train time 0.29 | train loss 1.743970e+00
# epoch   17 | train time 0.35 | train loss 1.653524e+00
# epoch   18 | train time 0.29 | train loss 1.564165e+00
# epoch   19 | train time 0.27 | train loss 1.475958e+00
# epoch   20 | train time 0.29 | train loss 1.388980e+00 | test loss 1.904609e+00 | test time 0.10
# epoch   21 | train time 0.26 | train loss 1.303412e+00
# epoch   22 | train time 0.29 | train loss 1.219621e+00
# epoch   23 | train time 0.37 | train loss 1.138208e+00
# epoch   24 | train time 0.33 | train loss 1.059988e+00
# epoch   25 | train time 0.33 | train loss 9.858273e-01
# epoch   26 | train time 0.30 | train loss 9.163610e-01
# epoch   27 | train time 0.33 | train loss 8.517696e-01
# epoch   28 | train time 0.32 | train loss 7.917278e-01
# epoch   29 | train time 0.33 | train loss 7.355899e-01
# epoch   30 | train time 0.32 | train loss 6.827479e-01 | test loss 9.619827e-01 | test time 0.12
# epoch   31 | train time 0.33 | train loss 6.329781e-01
# epoch   32 | train time 0.36 | train loss 5.865781e-01
# epoch   33 | train time 0.31 | train loss 5.442339e-01
# epoch   34 | train time 0.33 | train loss 5.067017e-01
# epoch   35 | train time 0.26 | train loss 4.744712e-01
# epoch   36 | train time 0.30 | train loss 4.475744e-01
# epoch   37 | train time 0.28 | train loss 4.255508e-01
# epoch   38 | train time 0.32 | train loss 4.074063e-01
# epoch   39 | train time 0.35 | train loss 3.915307e-01
# epoch   40 | train time 0.28 | train loss 3.759201e-01 | test loss 4.941067e-01 | test time 0.11
# epoch   41 | train time 0.32 | train loss 3.588990e-01
# epoch   42 | train time 0.36 | train loss 3.398326e-01
# epoch   43 | train time 0.34 | train loss 3.192118e-01
# epoch   44 | train time 0.31 | train loss 2.981847e-01
# epoch   45 | train time 0.28 | train loss 2.779817e-01
# epoch   46 | train time 0.27 | train loss 2.594807e-01
# epoch   47 | train time 0.30 | train loss 2.430123e-01
# epoch   48 | train time 0.30 | train loss 2.284369e-01
# epoch   49 | train time 0.27 | train loss 2.153033e-01
# epoch   50 | train time 0.32 | train loss 2.029868e-01 | test loss 2.909501e-01 | test time 0.13
# epoch   51 | train time 0.27 | train loss 1.909657e-01
# epoch   52 | train time 0.30 | train loss 1.791986e-01
# epoch   53 | train time 0.29 | train loss 1.680960e-01
# epoch   54 | train time 0.29 | train loss 1.579525e-01
# epoch   55 | train time 0.30 | train loss 1.485801e-01
# epoch   56 | train time 0.28 | train loss 1.394782e-01
# epoch   57 | train time 0.30 | train loss 1.302454e-01
# epoch   58 | train time 0.31 | train loss 1.212678e-01
# epoch   59 | train time 0.31 | train loss 1.135272e-01
# epoch   60 | train time 0.27 | train loss 1.073913e-01 | test loss 1.739610e-01 | test time 0.11
# epoch   61 | train time 0.28 | train loss 1.021967e-01
# epoch   62 | train time 0.31 | train loss 9.691730e-02
# epoch   63 | train time 0.28 | train loss 9.124604e-02
# epoch   64 | train time 0.29 | train loss 8.571673e-02
# epoch   65 | train time 0.34 | train loss 8.091230e-02
# epoch   66 | train time 0.34 | train loss 7.690396e-02
# epoch   67 | train time 0.33 | train loss 7.332396e-02
# epoch   68 | train time 0.30 | train loss 6.999771e-02
# epoch   69 | train time 0.30 | train loss 6.704213e-02
# epoch   70 | train time 0.41 | train loss 6.438389e-02 | test loss 1.024839e-01 | test time 0.10
# epoch   71 | train time 0.26 | train loss 6.169686e-02
# epoch   72 | train time 0.46 | train loss 5.882870e-02
# epoch   73 | train time 0.36 | train loss 5.608092e-02
# epoch   74 | train time 0.31 | train loss 5.379952e-02
# epoch   75 | train time 0.34 | train loss 5.191654e-02
# epoch   76 | train time 0.30 | train loss 5.005796e-02
# epoch   77 | train time 0.33 | train loss 4.807791e-02
# epoch   78 | train time 0.32 | train loss 4.619377e-02
# epoch   79 | train time 0.33 | train loss 4.459521e-02
# epoch   80 | train time 0.40 | train loss 4.321373e-02 | test loss 6.478419e-02 | test time 0.11
# epoch   81 | train time 0.39 | train loss 4.193920e-02
# epoch   82 | train time 0.33 | train loss 4.079194e-02
# epoch   83 | train time 0.33 | train loss 3.977147e-02
# epoch   84 | train time 0.31 | train loss 3.872944e-02
# epoch   85 | train time 0.32 | train loss 3.758449e-02
# epoch   86 | train time 0.30 | train loss 3.646586e-02
# epoch   87 | train time 0.31 | train loss 3.549602e-02
# epoch   88 | train time 0.28 | train loss 3.463322e-02
# epoch   89 | train time 0.31 | train loss 3.381415e-02
# epoch   90 | train time 0.27 | train loss 3.305818e-02 | test loss 4.954925e-02 | test time 0.10
# epoch   91 | train time 0.27 | train loss 3.237671e-02
# epoch   92 | train time 0.30 | train loss 3.171698e-02
# epoch   93 | train time 0.35 | train loss 3.105299e-02
# epoch   94 | train time 0.31 | train loss 3.042322e-02
# epoch   95 | train time 0.30 | train loss 2.984600e-02
# epoch   96 | train time 0.38 | train loss 2.928161e-02
# epoch   97 | train time 0.52 | train loss 2.870861e-02
# epoch   98 | train time 0.32 | train loss 2.815804e-02
# epoch   99 | train time 0.32 | train loss 2.765085e-02
# epoch  100 | train time 0.34 | train loss 2.716555e-02 | test loss 3.878875e-02 | test time 0.11
# horizon length : 25
# epoch  101 | train time 0.42 | train loss 6.750181e-02
# epoch  102 | train time 0.43 | train loss 4.978353e-02
# epoch  103 | train time 0.43 | train loss 5.111575e-02
# epoch  104 | train time 0.42 | train loss 5.645805e-02
# epoch  105 | train time 0.41 | train loss 4.896666e-02
# epoch  106 | train time 0.39 | train loss 4.264943e-02
# epoch  107 | train time 0.38 | train loss 4.440060e-02
# epoch  108 | train time 0.41 | train loss 4.163967e-02
# epoch  109 | train time 0.44 | train loss 3.571903e-02
# epoch  110 | train time 0.41 | train loss 3.822308e-02 | test loss 5.525525e-02 | test time 0.14
# epoch  111 | train time 0.41 | train loss 3.929580e-02
# epoch  112 | train time 0.38 | train loss 3.283052e-02
# epoch  113 | train time 0.38 | train loss 3.034886e-02
# epoch  114 | train time 0.41 | train loss 3.386799e-02
# epoch  115 | train time 0.45 | train loss 3.275870e-02
# epoch  116 | train time 0.49 | train loss 2.924564e-02
# epoch  117 | train time 0.39 | train loss 2.916458e-02
# epoch  118 | train time 0.42 | train loss 2.900415e-02
# epoch  119 | train time 0.43 | train loss 2.758293e-02
# epoch  120 | train time 0.43 | train loss 2.789066e-02 | test loss 3.813288e-02 | test time 0.14
# epoch  121 | train time 0.37 | train loss 2.728196e-02
# epoch  122 | train time 0.41 | train loss 2.491678e-02
# epoch  123 | train time 0.40 | train loss 2.489692e-02
# epoch  124 | train time 0.41 | train loss 2.564958e-02
# epoch  125 | train time 0.41 | train loss 2.417092e-02
# epoch  126 | train time 0.46 | train loss 2.274553e-02
# epoch  127 | train time 0.48 | train loss 2.294134e-02
# epoch  128 | train time 0.57 | train loss 2.258997e-02
# epoch  129 | train time 0.55 | train loss 2.173764e-02
# epoch  130 | train time 0.41 | train loss 2.148362e-02 | test loss 3.026899e-02 | test time 0.15
# epoch  131 | train time 0.39 | train loss 2.085759e-02
# epoch  132 | train time 0.37 | train loss 2.011365e-02
# epoch  133 | train time 0.44 | train loss 2.015886e-02
# epoch  134 | train time 0.48 | train loss 1.984484e-02
# epoch  135 | train time 0.63 | train loss 1.890201e-02
# epoch  136 | train time 0.40 | train loss 1.864799e-02
# epoch  137 | train time 0.39 | train loss 1.866104e-02
# epoch  138 | train time 0.48 | train loss 1.809101e-02
# epoch  139 | train time 0.48 | train loss 1.760502e-02
# epoch  140 | train time 0.40 | train loss 1.738808e-02 | test loss 2.457460e-02 | test time 0.13
# epoch  141 | train time 0.39 | train loss 1.698261e-02
# epoch  142 | train time 0.41 | train loss 1.666471e-02
# epoch  143 | train time 0.41 | train loss 1.642133e-02
# epoch  144 | train time 0.41 | train loss 1.593800e-02
# epoch  145 | train time 0.37 | train loss 1.559396e-02
# epoch  146 | train time 0.41 | train loss 1.546850e-02
# epoch  147 | train time 0.40 | train loss 1.509905e-02
# epoch  148 | train time 0.40 | train loss 1.468526e-02
# epoch  149 | train time 0.35 | train loss 1.449023e-02
# epoch  150 | train time 0.40 | train loss 1.423539e-02 | test loss 2.023123e-02 | test time 0.19
# epoch  151 | train time 0.48 | train loss 1.391408e-02
# epoch  152 | train time 0.36 | train loss 1.367086e-02
# epoch  153 | train time 0.39 | train loss 1.339480e-02
# epoch  154 | train time 0.36 | train loss 1.313519e-02
# epoch  155 | train time 0.39 | train loss 1.293992e-02
# epoch  156 | train time 0.36 | train loss 1.266201e-02
# epoch  157 | train time 0.40 | train loss 1.238429e-02
# epoch  158 | train time 0.38 | train loss 1.220376e-02
# epoch  159 | train time 0.38 | train loss 1.197553e-02
# epoch  160 | train time 0.36 | train loss 1.171451e-02 | test loss 1.716715e-02 | test time 0.14
# epoch  161 | train time 0.37 | train loss 1.151576e-02
# epoch  162 | train time 0.39 | train loss 1.130937e-02
# epoch  163 | train time 0.46 | train loss 1.109229e-02
# epoch  164 | train time 0.47 | train loss 1.089801e-02
# epoch  165 | train time 0.44 | train loss 1.068822e-02
# epoch  166 | train time 0.46 | train loss 1.049387e-02
# epoch  167 | train time 0.37 | train loss 1.032218e-02
# epoch  168 | train time 0.42 | train loss 1.012436e-02
# epoch  169 | train time 0.43 | train loss 9.938580e-03
# epoch  170 | train time 0.40 | train loss 9.779321e-03 | test loss 1.452835e-02 | test time 0.10
# epoch  171 | train time 0.39 | train loss 9.602874e-03
# epoch  172 | train time 0.31 | train loss 9.430652e-03
# epoch  173 | train time 0.35 | train loss 9.274343e-03
# epoch  174 | train time 0.53 | train loss 9.113264e-03
# epoch  175 | train time 0.36 | train loss 8.959691e-03
# epoch  176 | train time 0.36 | train loss 8.810011e-03
# epoch  177 | train time 0.34 | train loss 8.658664e-03
# epoch  178 | train time 0.40 | train loss 8.520181e-03
# epoch  179 | train time 0.51 | train loss 8.381145e-03
# epoch  180 | train time 0.50 | train loss 8.239130e-03 | test loss 1.242054e-02 | test time 0.19
# epoch  181 | train time 0.47 | train loss 8.109855e-03
# epoch  182 | train time 0.46 | train loss 7.981520e-03
# epoch  183 | train time 0.44 | train loss 7.851882e-03
# epoch  184 | train time 0.45 | train loss 7.730442e-03
# epoch  185 | train time 0.47 | train loss 7.610617e-03
# epoch  186 | train time 0.48 | train loss 7.493263e-03
# epoch  187 | train time 0.44 | train loss 7.379845e-03
# epoch  188 | train time 0.45 | train loss 7.266902e-03
# epoch  189 | train time 0.48 | train loss 7.159465e-03
# epoch  190 | train time 0.48 | train loss 7.054558e-03 | test loss 1.075753e-02 | test time 0.17
# epoch  191 | train time 0.46 | train loss 6.949173e-03
# epoch  192 | train time 0.44 | train loss 6.849197e-03
# epoch  193 | train time 0.45 | train loss 6.751627e-03
# epoch  194 | train time 0.46 | train loss 6.654410e-03
# epoch  195 | train time 0.36 | train loss 6.560884e-03
# epoch  196 | train time 0.36 | train loss 6.469257e-03
# epoch  197 | train time 0.45 | train loss 6.379669e-03
# epoch  198 | train time 0.47 | train loss 6.292350e-03
# epoch  199 | train time 0.46 | train loss 6.206229e-03
# epoch  200 | train time 0.39 | train loss 6.123048e-03 | test loss 9.407470e-03 | test time 0.12
# horizon length : 30
# epoch  201 | train time 0.43 | train loss 1.019509e-02
# epoch  202 | train time 0.56 | train loss 1.049580e-02
# epoch  203 | train time 0.55 | train loss 1.407497e-02
# epoch  204 | train time 0.49 | train loss 2.634322e-02
# epoch  205 | train time 0.40 | train loss 3.140739e-02
# epoch  206 | train time 0.48 | train loss 1.380624e-02
# epoch  207 | train time 0.51 | train loss 1.623957e-02
# epoch  208 | train time 0.57 | train loss 2.050957e-02
# epoch  209 | train time 0.43 | train loss 9.376151e-03
# epoch  210 | train time 0.44 | train loss 1.862192e-02 | test loss 1.581078e-02 | test time 0.20
# epoch  211 | train time 0.53 | train loss 9.826876e-03
# epoch  212 | train time 0.53 | train loss 1.484559e-02
# epoch  213 | train time 0.42 | train loss 1.171389e-02
# epoch  214 | train time 0.50 | train loss 1.097328e-02
# epoch  215 | train time 0.57 | train loss 1.301043e-02
# epoch  216 | train time 0.58 | train loss 8.400806e-03
# epoch  217 | train time 0.49 | train loss 1.246083e-02
# epoch  218 | train time 0.39 | train loss 7.764805e-03
# epoch  219 | train time 0.38 | train loss 1.142522e-02
# epoch  220 | train time 0.53 | train loss 8.135377e-03 | test loss 1.451144e-02 | test time 0.22
# epoch  221 | train time 0.50 | train loss 9.741945e-03
# epoch  222 | train time 0.50 | train loss 8.567180e-03
# epoch  223 | train time 0.53 | train loss 8.268889e-03
# epoch  224 | train time 0.54 | train loss 8.778766e-03
# epoch  225 | train time 0.45 | train loss 7.265433e-03
# epoch  226 | train time 0.43 | train loss 8.754440e-03
# epoch  227 | train time 0.43 | train loss 6.810516e-03
# epoch  228 | train time 0.65 | train loss 8.198462e-03
# epoch  229 | train time 0.59 | train loss 6.759950e-03
# epoch  230 | train time 0.45 | train loss 7.492723e-03 | test loss 1.042314e-02 | test time 0.14
# epoch  231 | train time 0.38 | train loss 6.900782e-03
# epoch  232 | train time 0.43 | train loss 6.789498e-03
# epoch  233 | train time 0.45 | train loss 6.946500e-03
# epoch  234 | train time 0.43 | train loss 6.331491e-03
# epoch  235 | train time 0.48 | train loss 6.831322e-03
# epoch  236 | train time 0.36 | train loss 6.056800e-03
# epoch  237 | train time 0.44 | train loss 6.575355e-03
# epoch  238 | train time 0.55 | train loss 5.965071e-03
# epoch  239 | train time 0.45 | train loss 6.201108e-03
# epoch  240 | train time 0.35 | train loss 5.950477e-03 | test loss 8.931478e-03 | test time 0.14
# epoch  241 | train time 0.36 | train loss 5.830003e-03
# epoch  242 | train time 0.43 | train loss 5.923958e-03
# epoch  243 | train time 0.48 | train loss 5.561068e-03
# epoch  244 | train time 0.44 | train loss 5.788160e-03
# epoch  245 | train time 0.38 | train loss 5.436465e-03
# epoch  246 | train time 0.39 | train loss 5.562443e-03
# epoch  247 | train time 0.44 | train loss 5.388184e-03
# epoch  248 | train time 0.49 | train loss 5.320228e-03
# epoch  249 | train time 0.43 | train loss 5.330990e-03
# epoch  250 | train time 0.35 | train loss 5.132221e-03 | test loss 8.171002e-03 | test time 0.14
# epoch  251 | train time 0.41 | train loss 5.216661e-03
# epoch  252 | train time 0.46 | train loss 5.026591e-03
# epoch  253 | train time 0.48 | train loss 5.055234e-03
# epoch  254 | train time 0.39 | train loss 4.964934e-03
# epoch  255 | train time 0.35 | train loss 4.889409e-03
# epoch  256 | train time 0.45 | train loss 4.893241e-03
# epoch  257 | train time 0.45 | train loss 4.762773e-03
# epoch  258 | train time 0.46 | train loss 4.782746e-03
# epoch  259 | train time 0.44 | train loss 4.682423e-03
# epoch  260 | train time 0.38 | train loss 4.652314e-03 | test loss 7.329763e-03 | test time 0.12
# epoch  261 | train time 0.45 | train loss 4.615513e-03
# epoch  262 | train time 0.44 | train loss 4.534089e-03
# epoch  263 | train time 0.51 | train loss 4.531461e-03
# epoch  264 | train time 0.63 | train loss 4.449154e-03
# epoch  265 | train time 0.44 | train loss 4.427440e-03
# epoch  266 | train time 0.35 | train loss 4.383468e-03
# epoch  267 | train time 0.46 | train loss 4.326092e-03
# epoch  268 | train time 0.50 | train loss 4.309655e-03
# epoch  269 | train time 0.47 | train loss 4.245955e-03
# epoch  270 | train time 0.39 | train loss 4.221240e-03 | test loss 6.592458e-03 | test time 0.17
# epoch  271 | train time 0.38 | train loss 4.181501e-03
# epoch  272 | train time 0.64 | train loss 4.134571e-03
# epoch  273 | train time 0.46 | train loss 4.112978e-03
# epoch  274 | train time 0.47 | train loss 4.063069e-03
# epoch  275 | train time 0.44 | train loss 4.034847e-03
# epoch  276 | train time 0.37 | train loss 4.000943e-03
# epoch  277 | train time 0.43 | train loss 3.959846e-03
# epoch  278 | train time 0.44 | train loss 3.936044e-03
# epoch  279 | train time 0.44 | train loss 3.895943e-03
# epoch  280 | train time 0.46 | train loss 3.866129e-03 | test loss 6.024655e-03 | test time 0.12
# epoch  281 | train time 0.31 | train loss 3.837238e-03
# epoch  282 | train time 0.49 | train loss 3.800396e-03
# epoch  283 | train time 0.56 | train loss 3.775360e-03
# epoch  284 | train time 0.45 | train loss 3.742675e-03
# epoch  285 | train time 0.44 | train loss 3.712429e-03
# epoch  286 | train time 0.40 | train loss 3.686721e-03
# epoch  287 | train time 0.52 | train loss 3.654483e-03
# epoch  288 | train time 0.45 | train loss 3.628675e-03
# epoch  289 | train time 0.45 | train loss 3.601233e-03
# epoch  290 | train time 0.41 | train loss 3.572090e-03 | test loss 5.556626e-03 | test time 0.16
# epoch  291 | train time 0.33 | train loss 3.547849e-03
# epoch  292 | train time 0.48 | train loss 3.519980e-03
# epoch  293 | train time 0.50 | train loss 3.493939e-03
# epoch  294 | train time 0.48 | train loss 3.469802e-03
# epoch  295 | train time 0.39 | train loss 3.443044e-03
# epoch  296 | train time 0.37 | train loss 3.419205e-03
# epoch  297 | train time 0.44 | train loss 3.395018e-03
# epoch  298 | train time 0.46 | train loss 3.369953e-03
# epoch  299 | train time 0.51 | train loss 3.347281e-03
# epoch  300 | train time 0.42 | train loss 3.323434e-03 | test loss 5.150634e-03 | test time 0.11
# horizon length : 35
# epoch  301 | train time 0.41 | train loss 7.005283e-03
# epoch  302 | train time 0.65 | train loss 8.530883e-03
# epoch  303 | train time 0.49 | train loss 8.754774e-03
# epoch  304 | train time 0.53 | train loss 7.258589e-03
# epoch  305 | train time 0.41 | train loss 6.128849e-03
# epoch  306 | train time 0.53 | train loss 6.606911e-03
# epoch  307 | train time 0.56 | train loss 7.631865e-03
# epoch  308 | train time 0.59 | train loss 6.640778e-03
# epoch  309 | train time 0.47 | train loss 5.670471e-03
# epoch  310 | train time 0.40 | train loss 5.798028e-03 | test loss 8.266064e-03 | test time 0.14
# epoch  311 | train time 0.51 | train loss 6.407159e-03
# epoch  312 | train time 0.51 | train loss 6.450013e-03
# epoch  313 | train time 0.50 | train loss 5.574966e-03
# epoch  314 | train time 0.52 | train loss 5.330930e-03
# epoch  315 | train time 0.46 | train loss 5.657224e-03
# epoch  316 | train time 0.54 | train loss 5.798282e-03
# epoch  317 | train time 0.53 | train loss 5.322337e-03
# epoch  318 | train time 0.58 | train loss 5.006750e-03
# epoch  319 | train time 0.46 | train loss 5.181031e-03
# epoch  320 | train time 0.46 | train loss 5.360626e-03 | test loss 6.813824e-03 | test time 0.23
# epoch  321 | train time 0.56 | train loss 5.033047e-03
# epoch  322 | train time 0.57 | train loss 4.765126e-03
# epoch  323 | train time 0.46 | train loss 4.892112e-03
# epoch  324 | train time 0.51 | train loss 4.938893e-03
# epoch  325 | train time 0.53 | train loss 4.753280e-03
# epoch  326 | train time 0.59 | train loss 4.575742e-03
# epoch  327 | train time 0.53 | train loss 4.671860e-03
# epoch  328 | train time 0.44 | train loss 4.671405e-03
# epoch  329 | train time 0.52 | train loss 4.513763e-03
# epoch  330 | train time 0.56 | train loss 4.404747e-03 | test loss 5.750548e-03 | test time 0.23
# epoch  331 | train time 0.52 | train loss 4.465582e-03
# epoch  332 | train time 0.46 | train loss 4.444849e-03
# epoch  333 | train time 0.49 | train loss 4.321528e-03
# epoch  334 | train time 0.58 | train loss 4.241072e-03
# epoch  335 | train time 0.56 | train loss 4.264945e-03
# epoch  336 | train time 0.45 | train loss 4.255132e-03
# epoch  337 | train time 0.40 | train loss 4.149687e-03
# epoch  338 | train time 0.50 | train loss 4.088430e-03
# epoch  339 | train time 0.52 | train loss 4.090792e-03
# epoch  340 | train time 0.62 | train loss 4.075476e-03 | test loss 5.361810e-03 | test time 0.16
# epoch  341 | train time 0.44 | train loss 3.997246e-03
# epoch  342 | train time 0.50 | train loss 3.948875e-03
# epoch  343 | train time 0.53 | train loss 3.937472e-03
# epoch  344 | train time 0.62 | train loss 3.921380e-03
# epoch  345 | train time 0.52 | train loss 3.862872e-03
# epoch  346 | train time 0.46 | train loss 3.820840e-03
# epoch  347 | train time 0.52 | train loss 3.803401e-03
# epoch  348 | train time 0.56 | train loss 3.782332e-03
# epoch  349 | train time 0.51 | train loss 3.736229e-03
# epoch  350 | train time 0.42 | train loss 3.696887e-03 | test loss 5.051024e-03 | test time 0.12
# epoch  351 | train time 0.52 | train loss 3.677211e-03
# epoch  352 | train time 0.50 | train loss 3.655389e-03
# epoch  353 | train time 0.54 | train loss 3.617385e-03
# epoch  354 | train time 0.48 | train loss 3.581694e-03
# epoch  355 | train time 0.47 | train loss 3.561175e-03
# epoch  356 | train time 0.54 | train loss 3.538981e-03
# epoch  357 | train time 0.66 | train loss 3.507864e-03
# epoch  358 | train time 0.53 | train loss 3.475484e-03
# epoch  359 | train time 0.42 | train loss 3.453094e-03
# epoch  360 | train time 0.53 | train loss 3.431259e-03 | test loss 4.621323e-03 | test time 0.19
# epoch  361 | train time 0.50 | train loss 3.404302e-03
# epoch  362 | train time 0.55 | train loss 3.374360e-03
# epoch  363 | train time 0.51 | train loss 3.350857e-03
# epoch  364 | train time 0.47 | train loss 3.329390e-03
# epoch  365 | train time 0.53 | train loss 3.305229e-03
# epoch  366 | train time 0.55 | train loss 3.278091e-03
# epoch  367 | train time 0.43 | train loss 3.254707e-03
# epoch  368 | train time 0.41 | train loss 3.233532e-03
# epoch  369 | train time 0.47 | train loss 3.211215e-03
# epoch  370 | train time 0.56 | train loss 3.186753e-03 | test loss 4.321013e-03 | test time 0.19
# epoch  371 | train time 0.54 | train loss 3.163783e-03
# epoch  372 | train time 0.52 | train loss 3.142755e-03
# epoch  373 | train time 0.45 | train loss 3.121815e-03
# epoch  374 | train time 0.54 | train loss 3.099350e-03
# epoch  375 | train time 0.59 | train loss 3.077123e-03
# epoch  376 | train time 0.45 | train loss 3.056493e-03
# epoch  377 | train time 0.44 | train loss 3.036436e-03
# epoch  378 | train time 0.60 | train loss 3.015581e-03
# epoch  379 | train time 0.54 | train loss 2.994502e-03
# epoch  380 | train time 0.50 | train loss 2.974393e-03 | test loss 4.025056e-03 | test time 0.14
# epoch  381 | train time 0.47 | train loss 2.954987e-03
# epoch  382 | train time 0.51 | train loss 2.935438e-03
# epoch  383 | train time 0.67 | train loss 2.915520e-03
# epoch  384 | train time 0.42 | train loss 2.896024e-03
# epoch  385 | train time 0.51 | train loss 2.877191e-03
# epoch  386 | train time 0.49 | train loss 2.858612e-03
# epoch  387 | train time 0.55 | train loss 2.839754e-03
# epoch  388 | train time 0.50 | train loss 2.821034e-03
# epoch  389 | train time 0.41 | train loss 2.802770e-03
# epoch  390 | train time 0.47 | train loss 2.784907e-03 | test loss 3.782399e-03 | test time 0.17
# epoch  391 | train time 0.58 | train loss 2.767000e-03
# epoch  392 | train time 0.55 | train loss 2.749117e-03
# epoch  393 | train time 0.41 | train loss 2.731456e-03
# epoch  394 | train time 0.44 | train loss 2.714203e-03
# epoch  395 | train time 0.52 | train loss 2.697096e-03
# epoch  396 | train time 0.60 | train loss 2.680023e-03
# epoch  397 | train time 0.46 | train loss 2.663041e-03
# epoch  398 | train time 0.39 | train loss 2.646361e-03
# epoch  399 | train time 0.53 | train loss 2.629902e-03
# epoch  400 | train time 0.54 | train loss 2.613578e-03 | test loss 3.556373e-03 | test time 0.22
# horizon length : 40
# epoch  401 | train time 0.49 | train loss 5.131469e-03
# epoch  402 | train time 0.60 | train loss 5.460356e-03
# epoch  403 | train time 0.63 | train loss 5.459984e-03
# epoch  404 | train time 0.62 | train loss 5.206369e-03
# epoch  405 | train time 0.54 | train loss 4.684643e-03
# epoch  406 | train time 0.62 | train loss 4.500488e-03
# epoch  407 | train time 0.66 | train loss 4.553815e-03
# epoch  408 | train time 0.49 | train loss 4.741815e-03
# epoch  409 | train time 0.51 | train loss 4.836048e-03
# epoch  410 | train time 0.60 | train loss 4.668536e-03 | test loss 5.999075e-03 | test time 0.22
# epoch  411 | train time 0.54 | train loss 4.426485e-03
# epoch  412 | train time 0.45 | train loss 4.174054e-03
# epoch  413 | train time 0.64 | train loss 4.064424e-03
# epoch  414 | train time 0.59 | train loss 4.041521e-03
# epoch  415 | train time 0.44 | train loss 4.090495e-03
# epoch  416 | train time 0.56 | train loss 4.095423e-03
# epoch  417 | train time 0.68 | train loss 4.027097e-03
# epoch  418 | train time 0.55 | train loss 3.894498e-03
# epoch  419 | train time 0.48 | train loss 3.773359e-03
# epoch  420 | train time 0.67 | train loss 3.717896e-03 | test loss 5.503304e-03 | test time 0.20
# epoch  421 | train time 0.59 | train loss 3.724581e-03
# epoch  422 | train time 0.54 | train loss 3.735918e-03
# epoch  423 | train time 0.55 | train loss 3.690179e-03
# epoch  424 | train time 0.70 | train loss 3.607992e-03
# epoch  425 | train time 0.56 | train loss 3.524448e-03
# epoch  426 | train time 0.53 | train loss 3.491808e-03
# epoch  427 | train time 0.63 | train loss 3.479459e-03
# epoch  428 | train time 0.65 | train loss 3.463273e-03
# epoch  429 | train time 0.62 | train loss 3.419758e-03
# epoch  430 | train time 0.46 | train loss 3.361081e-03 | test loss 5.049175e-03 | test time 0.22
# epoch  431 | train time 0.59 | train loss 3.313906e-03
# epoch  432 | train time 0.56 | train loss 3.280527e-03
# epoch  433 | train time 0.54 | train loss 3.265901e-03
# epoch  434 | train time 0.75 | train loss 3.244235e-03
# epoch  435 | train time 0.91 | train loss 3.211368e-03
# epoch  436 | train time 0.80 | train loss 3.166036e-03
# epoch  437 | train time 0.63 | train loss 3.122044e-03
# epoch  438 | train time 0.82 | train loss 3.091413e-03
# epoch  439 | train time 0.92 | train loss 3.068169e-03
# epoch  440 | train time 0.75 | train loss 3.048121e-03 | test loss 4.579739e-03 | test time 0.21
# epoch  441 | train time 0.57 | train loss 3.019521e-03
# epoch  442 | train time 0.74 | train loss 2.986444e-03
# epoch  443 | train time 0.74 | train loss 2.953007e-03
# epoch  444 | train time 0.55 | train loss 2.924132e-03
# epoch  445 | train time 0.71 | train loss 2.900918e-03
# epoch  446 | train time 0.75 | train loss 2.878095e-03
# epoch  447 | train time 0.55 | train loss 2.854527e-03
# epoch  448 | train time 0.62 | train loss 2.826923e-03
# epoch  449 | train time 0.73 | train loss 2.798524e-03
# epoch  450 | train time 0.65 | train loss 2.771612e-03 | test loss 4.076635e-03 | test time 0.17
# epoch  451 | train time 0.60 | train loss 2.747633e-03
# epoch  452 | train time 0.92 | train loss 2.726104e-03
# epoch  453 | train time 0.65 | train loss 2.703742e-03
# epoch  454 | train time 0.55 | train loss 2.680415e-03
# epoch  455 | train time 0.73 | train loss 2.655515e-03
# epoch  456 | train time 0.71 | train loss 2.630904e-03
# epoch  457 | train time 0.57 | train loss 2.607561e-03
# epoch  458 | train time 0.74 | train loss 2.585605e-03
# epoch  459 | train time 0.72 | train loss 2.564920e-03
# epoch  460 | train time 0.57 | train loss 2.543988e-03 | test loss 3.745477e-03 | test time 0.18
# epoch  461 | train time 0.70 | train loss 2.522727e-03
# epoch  462 | train time 0.74 | train loss 2.500864e-03
# epoch  463 | train time 0.53 | train loss 2.479190e-03
# epoch  464 | train time 0.64 | train loss 2.458382e-03
# epoch  465 | train time 0.72 | train loss 2.438276e-03
# epoch  466 | train time 0.60 | train loss 2.418774e-03
# epoch  467 | train time 0.62 | train loss 2.399186e-03
# epoch  468 | train time 0.74 | train loss 2.379543e-03
# epoch  469 | train time 0.66 | train loss 2.359877e-03
# epoch  470 | train time 0.62 | train loss 2.340364e-03 | test loss 3.469107e-03 | test time 0.24
# epoch  471 | train time 0.76 | train loss 2.321359e-03
# epoch  472 | train time 0.58 | train loss 2.302773e-03
# epoch  473 | train time 0.62 | train loss 2.284587e-03
# epoch  474 | train time 0.79 | train loss 2.266493e-03
# epoch  475 | train time 0.64 | train loss 2.248391e-03
# epoch  476 | train time 0.60 | train loss 2.230379e-03
# epoch  477 | train time 0.70 | train loss 2.212507e-03
# epoch  478 | train time 0.65 | train loss 2.194957e-03
# epoch  479 | train time 0.57 | train loss 2.177706e-03
# epoch  480 | train time 0.73 | train loss 2.160743e-03 | test loss 3.215473e-03 | test time 0.25
# epoch  481 | train time 0.58 | train loss 2.143994e-03
# epoch  482 | train time 0.61 | train loss 2.127341e-03
# epoch  483 | train time 0.70 | train loss 2.110798e-03
# epoch  484 | train time 0.65 | train loss 2.094365e-03
# epoch  485 | train time 0.60 | train loss 2.078113e-03
# epoch  486 | train time 0.74 | train loss 2.062091e-03
# epoch  487 | train time 0.70 | train loss 2.046274e-03
# epoch  488 | train time 0.54 | train loss 2.030662e-03
# epoch  489 | train time 0.65 | train loss 2.015197e-03
# epoch  490 | train time 0.73 | train loss 1.999875e-03 | test loss 2.958399e-03 | test time 0.20
# epoch  491 | train time 0.57 | train loss 1.984678e-03
# epoch  492 | train time 0.66 | train loss 1.969605e-03
# epoch  493 | train time 0.78 | train loss 1.954703e-03
# epoch  494 | train time 0.59 | train loss 1.939961e-03
# epoch  495 | train time 0.65 | train loss 1.925387e-03
# epoch  496 | train time 0.71 | train loss 1.910966e-03
# epoch  497 | train time 0.62 | train loss 1.896687e-03
# epoch  498 | train time 0.66 | train loss 1.882541e-03
# epoch  499 | train time 0.76 | train loss 1.868519e-03

# %% [markdown]
# # Result plots

# %% [markdown]
# ## plot functions

# %%
def train_test_loss_plot(loss_train,loss_test, epochs, file_path=None,
                            horizons = [100,150,200,250,300],
                            horizon_steps = [200,400,550,700,850],
                            title='train and test loss per epoch' ):
    ''' 
    Description:

    Inputs:

    Outpus:

    '''
    fig, ax = plt.subplots(figsize=(10,4))
    # ,constrained_layout=True)
    # fig.tight_layout()

    plt.plot(epochs, loss_train, label='train')

    if not loss_test == []: # if loss_test exists
        plt.plot(epochs[::10], loss_test, label='test')

    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.yscale('log')
    plt.legend()
    plt.title(title)

    if horizons:
        for i, epoch_num in enumerate(horizon_steps[:-1]):
            ax.annotate(
            'horizon = %d'%horizons[i],
            xy=(epochs[epoch_num], loss_train[epoch_num]), xycoords='data',
            xytext=(-70, 100), textcoords='offset points',
            arrowprops=dict(arrowstyle="->",
                            #connectionstyle="arc,angleA=0,armA=50,rad=10"
                            connectionstyle="angle,angleA=0,angleB=90,rad=10"
                            ))
        ax.annotate(
        'horizon = %d'%horizons[-1],
        xy=(epochs[horizon_steps[-1]], loss_train[horizon_steps[-1]]), xycoords='data',
        xytext=(+20, 100), textcoords='offset points',
        arrowprops=dict(arrowstyle="->",
                        #connectionstyle="arc,angleA=0,armA=50,rad=10"
                        connectionstyle="angle,angleA=0,angleB=90,rad=10"
                        ))

    if file_path is not None:
        plt.savefig(file_path, format="png",dpi=400)#,bbox_inches='tight') # dpi
        # plt.savefig(file_path, format="pdf", bbox_inches="tight")
    plt.show()
   
    return

# %%
def plot_results(model, train_loader, train_horizon, n, u_func, g_func, C, m, g, l, file_path, show_pred = True, title = 'Trajectory of the generalized coordinates', coord_type = 'hamiltonian'):
    x, t_eval = next(iter(train_loader)) 
    t_eval = t_eval[0,:]
    test_x_hat = odeint(model, x[n:n+1, 0, :], t_eval, method='rk4') 

    energy_nom, _ = get_energy_pendulum(t_eval, u_func, g_func, x[n, :, 0], x[n, :, 1], C, m, g, l)
    energy_pred, _ = get_energy_pendulum(t_eval, u_func, g_func, test_x_hat[:, 0, 0], test_x_hat[:, 0, 1], C, m, g, l)
    input = u_func.forward(t_eval).cpu().detach()
    t_eval = t_eval.cpu().detach()
    
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(12, 4),constrained_layout=True)#, sharex=True)# , sharey=True)

    fig.suptitle(title, fontsize=12)

    for q, p, energy, label,color in [(x[n,:,0],x[n,:,1], energy_nom, 'nominal','C0'),(test_x_hat[:, 0, 0], test_x_hat[:, 0, 1], energy_pred, 'train','g')]:
        q = q.cpu().detach()
        p = p.cpu().detach()
        energy = energy.cpu().detach()
        
        ax1.plot(t_eval, q, label=label, color=color)
        ax3.plot(t_eval, energy, label=label, color=color)
        ax2.plot(t_eval, p, label=label, color=color)

        if show_pred==True and label=='train' :
            ax1.plot(t_eval[(train_horizon-1):], q[(train_horizon-1):], label='predicted', color='r')
            ax2.plot(t_eval[train_horizon-1:], p[train_horizon-1:], label='predicted', color='r')
            ax3.plot(t_eval[train_horizon-1:], energy[train_horizon-1:], label='predicted', color='r')
        
        
        ax1.legend()
        ax1.set_title('generalized position (q)', fontsize=10)
        ax1.set_xlabel('time (s)')
        ax1.set_ylabel('q')

        # ax2.legend()
        ax2.set_title('generalized momentum (p)', fontsize=10)
        ax2.set_xlabel('time (s)')
        ax2.set_ylabel('p')


        # ax3.legend()
        ax3.set_title('Energy', fontsize=10)
        ax3.set_xlabel('time (s)')
        ax3.set_ylabel('E')
        ax3.set_ylim((0,torch.max(energy)*1.1))

    ax4.plot(t_eval, input, label='input')
    ax4.set_title('Input', fontsize=10)
    ax4.set_xlabel('time (s)')
    ax4.set_ylabel('U')
    # ax4.legend()
    # ax4.set_ylim((0,torch.max(input)*1.1))

    if coord_type == 'newtonian':
        ax2.set_title(r'$\dot{q}[rad/s]$', fontsize=10)
        ax2.set_ylabel(r'$\dot{q}[rad/s]$')
        
    if file_path is not None:
        plt.savefig(file_path, format="png",dpi=400)#,bbox_inches='tight') # dpi
        # plt.savefig(file_path, format="pdf", bbox_inches="tight")
    plt.show()
    return

# %% [markdown]
# ## Plots

# %%
import numpy as np

# %%
loss_train = stats['train_loss']
loss_test = stats['test_loss']
epochs = np.arange(len(loss_train))
train_test_loss_plot(loss_train, loss_test, epochs, file_path='../data/img/simple_pend_chirp_withnn.png',
                            horizons = None,
                            horizon_steps = [200,400,550,700,850],
                            title='train and test loss per epoch' )

# %%
model.u_func = U_FUNC(utype='chirp')
model.u_func.params['T'] = 2.0
model.u_func.params['f0'] = 0
model.u_func.params['f1'] = 1
model.u_func.params['scale'] = 1

# %%
train_horizon=40

# %%
plot_results(model, train_loader, train_horizon, 10, u_func, 
        g_func, C, m, g, l, file_path='../data/img/simple_pend_CHIRP_with_NN.png', show_pred = False, 
        title ='NesHDNN trained on CHIRP ',coord_type = 'hamiltonian')

# %%
for n in range(10,15):
    plot_results(model, train_loader, train_horizon, n, u_func, g_func, C, m, g, l, file_path=None, show_pred = False, title ='Simple pendulum with CHIRP input',coord_type = 'hamiltonian')

# %%
u_func_none = U_FUNC(utype=None)

# %%
train_loader_no_input, test_loader_no_input = load_data_device(time_steps=200, num_trajectories=125, device=device, batch_size=100, proportion=0.8, shuffle=False, Ts=Ts, y0=y0, 
                                noise_std=noise_std, C=C, m=m, g=g, l=l, u_func=u_func_none, g_func=g_func, coord_type = 'hamiltonian')

# %%
model.u_func = U_FUNC(utype=None)

# %%
plot_results(model, train_loader_no_input, train_horizon, 10, u_func_none, 
        g_func, C, m, g, l, file_path='../data/img/simple_pend_noinput_with_NN.png', show_pred = True, 
        title ='NesHDNN trained on CHIRP and tested on no input',coord_type = 'hamiltonian')

# %%
plot_results(model, train_loader_no_input, train_horizon, 14, u_func_none, 
        g_func, C, m, g, l, file_path='../data/img/simple_pend_noinput_2withnn.png', show_pred = True, 
        title ='Same model without the input',coord_type = 'hamiltonian')

# %%
for n in range(10,15):
    plot_results(model, train_loader_no_input, train_horizon, n, u_func_none, g_func, C, m, g, l, file_path=None, show_pred = True, title ='Same model without the input', coord_type = 'hamiltonian')

# %%
model.G_net
# Out:
# MLP(
#   (fc1): Linear(in_features=2, out_features=40, bias=True)
#   (hidden_layers): Sequential(
#     (0): hidden_Layer(
#       (fc): Linear(in_features=40, out_features=40, bias=True)
#     )
#   )
#   (fc2): Linear(in_features=40, out_features=2, bias=True)
# )

# %%
x,t = next(iter(train_loader))

# %%
x.shape
# Out:
# torch.Size([100, 40, 2])

# %%
x[0,0,:]
# Out:
# tensor([0.5692, 0.0000])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,4))
  
# plt.suptitle('test')
ax[0].hist(model.G_net(x[0,:,:]).detach().numpy()[:,0])
ax[0].set_title(r'${\tilde{G} [0]}$')
ax[0].set_xlabel('count')
ax[0].set_ylabel('value')
ax[1].hist(model.G_net(x[0,:,:]).detach().numpy()[:,1])
ax[1].set_title(r'${\tilde{G} [1]}$')
ax[1].set_xlabel('count')
ax[1].set_ylabel('value')

plt.savefig('../data/img/G_distribution.png', format="png",dpi=400)

# %%
for n in range(5):
    plt.plot(model.H_net(x[n,:,:]).detach().numpy())
